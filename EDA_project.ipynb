# %%
import pandas as pd

# Load the dataset
file_path = 'household_power_consumption.txt'  # Replace with your file path
data = pd.read_csv(file_path, delimiter=';', parse_dates={'Datetime': ['Date', 'Time']}, infer_datetime_format=True, low_memory=False, na_values=['nan','?'])

# %%
data
# Out:
#                    Datetime  Global_active_power  Global_reactive_power  \
# 0       2006-12-16 17:24:00                4.216                  0.418
# 1       2006-12-16 17:25:00                5.360                  0.436
# 2       2006-12-16 17:26:00                5.374                  0.498
# 3       2006-12-16 17:27:00                5.388                  0.502
# 4       2006-12-16 17:28:00                3.666                  0.528
# ...                     ...                  ...                    ...
# 2075254 2010-11-26 20:58:00                0.946                  0.000
# 2075255 2010-11-26 20:59:00                0.944                  0.000
# 2075256 2010-11-26 21:00:00                0.938                  0.000
# 2075257 2010-11-26 21:01:00                0.934                  0.000
# 2075258 2010-11-26 21:02:00                0.932                  0.000
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...

# %%
missing_values = data.isnull().sum()

# %%
missing_values
# Out:
# Datetime                     0
# Global_active_power      25979
# Global_reactive_power    25979
# Voltage                  25979
# Global_intensity         25979
# Sub_metering_1           25979
# Sub_metering_2           25979
# Sub_metering_3           25979
# dtype: int64

# %%
data_clean = data.dropna()

# %%
data_clean
# Out:
#                    Datetime  Global_active_power  Global_reactive_power  \
# 0       2006-12-16 17:24:00                4.216                  0.418
# 1       2006-12-16 17:25:00                5.360                  0.436
# 2       2006-12-16 17:26:00                5.374                  0.498
# 3       2006-12-16 17:27:00                5.388                  0.502
# 4       2006-12-16 17:28:00                3.666                  0.528
# ...                     ...                  ...                    ...
# 2075254 2010-11-26 20:58:00                0.946                  0.000
# 2075255 2010-11-26 20:59:00                0.944                  0.000
# 2075256 2010-11-26 21:00:00                0.938                  0.000
# 2075257 2010-11-26 21:01:00                0.934                  0.000
# 2075258 2010-11-26 21:02:00                0.932                  0.000
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...

# %%
missing_values
# Out:
# Datetime                     0
# Global_active_power      25979
# Global_reactive_power    25979
# Voltage                  25979
# Global_intensity         25979
# Sub_metering_1           25979
# Sub_metering_2           25979
# Sub_metering_3           25979
# dtype: int64

# %%
data
# Out:
#                    Datetime  Global_active_power  Global_reactive_power  \
# 0       2006-12-16 17:24:00                4.216                  0.418
# 1       2006-12-16 17:25:00                5.360                  0.436
# 2       2006-12-16 17:26:00                5.374                  0.498
# 3       2006-12-16 17:27:00                5.388                  0.502
# 4       2006-12-16 17:28:00                3.666                  0.528
# ...                     ...                  ...                    ...
# 2075254 2010-11-26 20:58:00                0.946                  0.000
# 2075255 2010-11-26 20:59:00                0.944                  0.000
# 2075256 2010-11-26 21:00:00                0.938                  0.000
# 2075257 2010-11-26 21:01:00                0.934                  0.000
# 2075258 2010-11-26 21:02:00                0.932                  0.000
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...

# %%
summary_statistics = data_clean.describe()

# %%
summary_statistics
# Out:
#        Global_active_power  Global_reactive_power       Voltage  \
# count         2.049280e+06           2.049280e+06  2.049280e+06
# mean          1.091615e+00           1.237145e-01  2.408399e+02
# std           1.057294e+00           1.127220e-01  3.239987e+00
# min           7.600000e-02           0.000000e+00  2.232000e+02
# 25%           3.080000e-01           4.800000e-02  2.389900e+02
# 50%           6.020000e-01           1.000000e-01  2.410100e+02
# 75%           1.528000e+00           1.940000e-01  2.428900e+02
# max           1.112200e+01           1.390000e+00  2.541500e+02
#
#        Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# count      2.049280e+06    2.049280e+06    2.049280e+06    2.049280e+06
# mean       4.627759e+00    1.121923e+00    1.298520e+00    6.458447e+00
# std        4.444396e+00    6.153031e+00    5.822026e+00    8.437154e+00
# min        2.000000e-01    0.000000e+00    0.000000e+00    0.000000e+00
# ...

# %%
data_types = data_clean.dtypes

# %%
data_types
# Out:
# Datetime                 datetime64[ns]
# Global_active_power             float64
# Global_reactive_power           float64
# Voltage                         float64
# Global_intensity                float64
# Sub_metering_1                  float64
# Sub_metering_2                  float64
# Sub_metering_3                  float64
# dtype: object

# %%
if data_clean['Datetime'].dtype == 'object':
    data_clean['Datetime'] = pd.to_datetime(data_clean['Datetime'])

# %%
data_clean
# Out:
#                    Datetime  Global_active_power  Global_reactive_power  \
# 0       2006-12-16 17:24:00                4.216                  0.418
# 1       2006-12-16 17:25:00                5.360                  0.436
# 2       2006-12-16 17:26:00                5.374                  0.498
# 3       2006-12-16 17:27:00                5.388                  0.502
# 4       2006-12-16 17:28:00                3.666                  0.528
# ...                     ...                  ...                    ...
# 2075254 2010-11-26 20:58:00                0.946                  0.000
# 2075255 2010-11-26 20:59:00                0.944                  0.000
# 2075256 2010-11-26 21:00:00                0.938                  0.000
# 2075257 2010-11-26 21:01:00                0.934                  0.000
# 2075258 2010-11-26 21:02:00                0.932                  0.000
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Assuming you have a pandas DataFrame df
# Generate descriptive statistics
descriptive_stats = data_clean.describe()

# Plot histograms for each feature in the data
data_clean.hist(figsize=(10, 8))
plt.tight_layout()
plt.show()

# %%
# Create a box plot for each feature to visualize the distributions and see outliers
plt.figure(figsize=(10, 8))
data.boxplot()
plt.show()

# %%
# Create scatter plots to visualize relationships between pairs of variables
sns.pairplot(data_clean)
plt.show()

# %%
# Generate a correlation matrix heatmap to check for correlations between variables
plt.figure(figsize=(10, 8))
correlation_matrix = data.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
# The descriptive statistics can be printed or saved to a variable for further analysis
print(descriptive_stats)
# Out:
#        Global_active_power  Global_reactive_power       Voltage  \
# count         2.049280e+06           2.049280e+06  2.049280e+06
# mean          1.091615e+00           1.237145e-01  2.408399e+02
# std           1.057294e+00           1.127220e-01  3.239987e+00
# min           7.600000e-02           0.000000e+00  2.232000e+02
# 25%           3.080000e-01           4.800000e-02  2.389900e+02
# 50%           6.020000e-01           1.000000e-01  2.410100e+02
# 75%           1.528000e+00           1.940000e-01  2.428900e+02
# max           1.112200e+01           1.390000e+00  2.541500e+02
#
#        Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# count      2.049280e+06    2.049280e+06    2.049280e+06    2.049280e+06
# mean       4.627759e+00    1.121923e+00    1.298520e+00    6.458447e+00
# std        4.444396e+00    6.153031e+00    5.822026e+00    8.437154e+00
# min        2.000000e-01    0.000000e+00    0.000000e+00    0.000000e+00
# ...

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Load your data into a pandas DataFrame
# df = pd.read_csv('path_to_your_data.csv')

# Ensure the datetime column is in the correct data type
# df['Datetime'] = pd.to_datetime(df['Datetime'])

# Feature Engineering: Derive new features
data_clean['hour_of_day'] = data_clean['Datetime'].dt.hour
data_clean['day_of_week'] = data_clean['Datetime'].dt.dayofweek
data_clean['is_weekend'] = data_clean['day_of_week'].apply(lambda x: 1 if x >= 5 else 0)

# Normalize or standardize the data
scaler = StandardScaler()

# Assume these are the features you want to scale
features_to_scale = ['Global_active_power', 'Global_reactive_power', 'Voltage', 'Global_intensity']

# Perform scaling on the features
data_clean[features_to_scale] = scaler.fit_transform(data_clean[features_to_scale])

# The DataFrame 'df' is now updated with new features and scaled values
print(data_clean.head())
# Out:
# C:\Users\rohit\AppData\Local\Temp/ipykernel_9500/65832941.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_clean['hour_of_day'] = data_clean['Datetime'].dt.hour
# C:\Users\rohit\AppData\Local\Temp/ipykernel_9500/65832941.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_clean['day_of_week'] = data_clean['Datetime'].dt.dayofweek
# C:\Users\rohit\AppData\Local\Temp/ipykernel_9500/65832941.py:13: SettingWithCopyWarning:
# ...
